# %%
import requests
import pandas as pd
import sqlalchemy
import bs4 as bs
import numpy as np

# %% [markdown]
# ## Scrapping single page

# %% [markdown]
# ### HTTP Request

# %%
# Store website in a variable
website = 'https://www.justia.com/lawyers/new-york/new-york-city'
# Get request
response = requests.get(website)

# %%
# Status code = request has been made successfully
response
# Out:
# <Response [200]>

# %%
# Soup object
soup = bs.BeautifulSoup(response.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" xml:lang="en">
#  <head prefix="og: http://ogp.me/ns#">
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    New York City Lawyers - Compare Top Attorneys in New York City, New York - Justia
#   </title>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="Compare 1000+ attorneys serving New York City, New York on Justia. Comprehensive lawyer profiles including fees, education, jurisdictions, awards, publications and social media." name="description"/>
#   <meta content="Lawyer, Attorney, Lawyers, Attorneys, New York City, New York" name="keywords"/>
#   <meta content="index,follow" name="robots"/>
#   <link href="https://www.justia.com/lawyers/new-york/new-york-city" rel="canonical"/>
#   <link href="https://www.justia.com/lawyers/new-york/new-york-city?amp" rel="amphtml"/>
#   <link href="https://www.justia.com/lawyers/new-york/new-york-city?page=2" rel="next"/>
#   <meta content="website" property="og:type">
#    <meta content="https://www.justia.com/lawyers/new-york/new-york-city" property="og:url"/>
#    <meta content="https://www.justia.com/lawyers/new-york/new-york-city" name="twitter:url"/>
#    <meta content="summary" name="twitter:card"/>
#    <meta content="www.justia.com" name="twitter:domain"/>
#    <meta content="@JustiaCom" name="twitter:site"/>
#    <meta content="https://static.justia.com/images/justia-social.png" property="og:image"/>
#    <meta content="https://static.justia.com/images/justia-social.png" name="twitter:image"/>
#    <meta content="New York City Lawyers - Compare Top Attorneys in New York City, New York - Justia" property="og:title"/>
#    <meta content="New York City Lawyers - Compare Top Attorneys in New York City, New York - Justia" name="twitter:title"/>
#    <meta content="Compare 1000+ attorneys serving New York City, New York on Justia. Comprehensive lawyer profiles including fees, education, jurisdictions, awards, publications and social media." property="og:description"/>
#    <meta content="Compare 1000+ attorneys serving New York City, New York on Justia. Comprehensive lawyer profiles including fees, education, jurisdictions, awards, publications and social media." name="twitter:description"/>
#    <meta content="origin" name="referrer"/>
#    <meta content="unsafe-url" name="referrer"/>
#    <link href="https://justatic.com/v/20220131150237/shared/css/core.css" media="all" rel="stylesheet" type="text/css"/>
#    <link href="https://justatic.com" rel="preconnect"/>
#    <link href="https://www.googletagmanager.com" rel="preconnect"/>
#    <link href="https://www.google-analytics.com" rel="preconnect"/>
#    <meta content="0" name="is-li"/>
#    <meta content="ListingPageByCity" name="page-type-t"/>
#    <meta content="Directory: Listing Page by City" name="page-type"/>
#    <link href="https://justatic.com/v/20220131150237/branding/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#    <link href="https://justatic.com/v/20220131150237/shared/images/justia/jbutton_flat_144.svg" rel="icon" type="image/svg+xml"/>
#    <link href="https://justatic.com/v/20220131150237/shared/images/justia/jbutton_flat_144.png" rel="icon" sizes="144x144" type="image/png"/>
#    <link href="https://justatic.com/v/20220131150237/shared/images/justia/jbutton_flat_128.png" rel="icon" sizes="128x128" type="image/png"/>
#    <link href="https://justatic.com/v/20220131150237/shared/images/justia/justia.ico" rel="icon" sizes="16x16 24x24 32x32 48x48 64x64 96x96 128x128" type="image/x-icon"/>
#    <link href="https://justatic.com/v/20220131150237/shared/images/justia/jbutton_flat_57.png" rel="apple-touch-icon" sizes="57x57" type="image/png"/>
#    <link href="https://justatic.com/v/20220131150237/shared/images/justia/jbutton_flat_72.png" rel="apple-touch-icon" sizes="72x72" type="image/png"/>
#    <link href="https://justatic.com/v/20220131150237/shared/images/justia/jbutton_flat_114.png" rel="apple-touch-icon" sizes="114x114" type="image/png"/>
#    <link href="https://justatic.com/v/20220131150237/shared/images/justia/jbutton_flat_144.png" rel="apple-touch-icon" sizes="144x144" type="image/png"/>
#    <link href="https://justatic.com/v/20220131150237/shared/images/justia/jbutton_3d_57.png" rel="apple-touch-icon-precomposed" sizes="57x57" type="image/png"/>
#    <link href="https://justatic.com/v/20220131150237/shared/images/justia/jbutton_3d_72.png" rel="apple-touch-icon-precomposed" sizes="72x72" type="image/png"/>
#    <link href="https://justatic.com/v/20220131150237/shared/images/justia/jbutton_3d_114.png" rel="apple-touch-icon-precomposed" sizes="114x114" type="image/png"/>
#    <link href="https://justatic.com/v/20220131150237/shared/images/justia/jbutton_3d_144.png" rel="apple-touch-icon-precomposed" sizes="144x144" type="image/png"/>
#    <link href="https://justatic.com/v/20220131150237/shared/images/justia/justia.ico" rel="shortcut icon" sizes="16x16 24x24 32x32 48x48 64x64 96x96 128x128" type="image/vnd.microsoft.icon"/>
#    <meta content="1" name="trigger-ga"/>
#    <script type="application/ld+json">
#     {"@context":"https:\/\/schema.org\/","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Justia","item":"http:\/\/www.justia.com\/"},{"@type":"ListItem","position":2,"name":"Lawyer Directory","item":"https:\/\/www.justia.com\/lawyers"},{"@type":"ListItem","position":3,"name":"New York","item":"http:\/\/www.justia.com\/lawyers\/new-york"},{"@type":"ListItem","position":4,"name":"New York City Attorneys"}]}
#    </script>
#    <script type="application/ld+json">
#     {"@context":"https:\/\/schema.org\/","@type":"City","name":"New York City","containedIn":{"@type":"State","name":"New York"}}
#    </script>
#    <script type="application/ld+json">
#     [{"@context":"https:\/\/schema.org\/","@type":"Person","url":"https:\/\/lawyers.justia.com\/lawyer\/eric-weiss-esq-1492272","name":"Eric Weiss Esq.","telephone":"(914) 328-6100","image":{"@type":"ImageObject","url":"https:\/\/justatic.com\/profile-images\/1492272-1444778637-sl.jpg"},"alumniOf":[{"@type":"CollegeOrUniversity","name":"Fordham University School of Law"}]},{"@context":"https:\/\/schema.org\/","@type":"Person","url":"https:\/\/lawyers.justia.com\/lawyer\/steven-m-yurkonis-1531612","name":"Steven M. Yurkonis","telephone":"(800) 518-4529","image":{"@type":"ImageObject","url":"https:\/\/justatic.com\/profile-images\/1531612-1579277449-sl.jpg"},"alumniOf":[{"@type":"CollegeOrUniversity","name":"Syracuse University College of Law"}]},{"@context":"https:\/\/schema.org\/","@type":"Person","url":"https:\/\/lawyers.justia.com\/lawyer\/donnell-much-1666096","name":"Donnell Much","telephone":"(800) 810-4262","image":{"@type":"ImageObject","url":"https:\/\/justatic.com\/profile-images\/1666096-1629823103-sl.jpeg"},"alumniOf":[{"@type":"CollegeOrUniversity","name":"Georgetown University Law Center"},{"@type":"CollegeOrUniversity","name":"Loyola University New Orleans College of Law"}]},{"@context":"https:\/\/schema.org\/","@type":"Person","url":"https:\/\/lawyers.justia.com\/lawyer\/nathalie-l-bell-1280463","name":"Nathalie L. Bell","telephone":"(855) 566-2355","image":{"@type":"ImageObject","url":"https:\/\/justatic.com\/profile-images\/1280463-1610664482-sl.jpg"},"alumniOf":[{"@type":"CollegeOrUniversity","name":"New York Law School"}]},{"@context":"https:\/\/schema.org\/","@type":"Person","url":"https:\/\/lawyers.justia.com\/lawyer\/adam-leitman-bailey-1236057","name":"Adam Leitman Bailey","image":{"@type":"ImageObject","url":"https:\/\/justatic.com\/profile-images\/1236057-1575649502-sl.jpg"},"workLocation":{"@type":"LegalService","image":{"@type":"ImageObject","url":"https:\/\/justatic.com\/v\/20220131150237\/shared\/images\/directory\/location.png"},"telephone":"(212) 825-0365","geo":{"@type":"GeoCoordinates","latitude":"40.7033758","longitude":"-74.0138065"},"name":"Adam Leitman Bailey, P.C.","address":{"@type":"PostalAddress","streetAddress":["One Battery Park Plaza","Eighteenth Floor"],"addressLocality":"New York","addressRegion":"NY","postalCode":"10004"}},"alumniOf":[{"@type":"CollegeOrUniversity","name":"Syracuse University College of Law"}]},{"@context":"https:\/\/schema.org\/","@type":"Person","url":"https:\/\/lawyers.justia.com\/lawyer\/russel-morgan-1528786","name":"Russel Morgan","image":{"@type":"ImageObject","url":"https:\/\/justatic.com\/profile-images\/1528786-1542056432-sl.jpg"},"workLocation":{"@type":"LegalService","image":{"@type":"ImageObject","url":"https:\/\/justatic.com\/v\/20220131150237\/shared\/images\/directory\/location.png"},"telephone":"(212) 561-4299","geo":{"@type":"GeoCoordinates","latitude":"40.7150606","longitude":"-74.0058265"},"name":"Main\/Manhattan Office","address":{"@type":"PostalAddress","streetAddress":["299 Broadway, 17th Floor"],"addressLocality":"New York","addressRegion":"NY","postalCode":"10007"}},"alumniOf":[{"@type":"CollegeOrUniversity","name":"New York Law School"}]},{"@context":"https:\/\/schema.org\/","@type":"Person","url":"https:\/\/lawyers.justia.com\/lawyer\/jenice-malecki-1208105","name":"Jenice Malecki","image":{"@type":"ImageObject","url":"https:\/\/justatic.com\/profile-images\/1208105-1556922837-sl.jpg"},"workLocation":{"@type":"LegalService","image":{"@type":"ImageObject","url":"https:\/\/justatic.com\/v\/20220131150237\/shared\/images\/directory\/location.png"},"telephone":"(212) 943-1233","geo":{"@type":"GeoCoordinates","latitude":"40.7052799","longitude":"-74.0140249"},"name":"Malecki Law","address":{"@type":"PostalAddress","streetAddress":["11 Broadway","#715"],"addressLocality":"New York","addressRegion":"NY","postalCode":"10004"}},"alumniOf":[{"@type":"CollegeOrUniversity","name":"New York Law School"}]},{"@context":"https:\/\/schema.org\/","@type": ...
#    </script>
#    <!-- Google Tag Manager -->
#    <script>
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-P2QTGCR');
#    </script>
#    <!-- End Google Tag Manager -->
#   </meta>
#  </head>
#  <body class="justia drupal ld-listings lawyer-directory jld-v4 justiav4 justia_v4 sticky-footer" data-project="lawyers" data-ts="1643807287">
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-P2QTGCR" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <header data-directive="j-topnav" id="header">
#    <div id="sticky-nav">
#     <div class="burger-wrapper">
#      <div class="hamburger" data-gtm-action="Header" data-gtm-category="Navigation" data-gtm-label="Hamburger" data-gtm-type="click" id="hamburger">
#       <div class="inner-ham" data-gtm-action="Header" data-gtm-category="Navigation" data-gtm-label="Hamburger" data-gtm-type="click">
#        <span class="lns ln2-1">
#        </span>
#        <span class="lns ln2-2">
#        </span>
#       </div>
#      </div>
#      <div id="header-nav">
#       <div class="inner-wrapper">
#        <div class="logo-wrapper">
#         <a class="logo" href="https://www.justia.com/lawyers" title="Justia Lawyer Directory">
#          <img alt="Justia" height="36" onerror="this.onerror=null; this.src='https://justatic.com/v/20220131150237/shared/images/logos/justia.png'" src="https://justatic.com/v/20220131150237/shared/images/logos/justia.svg" width="190"/>
#          <img alt="Justia Lawyers" class="sub-domain" height="26" onerror="this.onerror=null; this. src='https://justatic.com/v/20220131150237/shared/images/logos/justia-lawyers.png'" src="https://justatic.com/v/20220131150237/shared/images/logos/justia-lawyers.svg" width="119"/>
#         </a>
#        </div>
#        <div class="gameover">
#         <div class="buttons-wrapper">
#          <div class="topnav-button search-icon" id="search-icon-button">
#           <img alt="Search" height="20" src="https://justatic.com/v/20220131150237/shared/images/icons/svgfiles/white/search.svg" width="20">
#           </img>
#          </div>
#          <div class="topnav-button sign-in-icon" id="sign-in-icon-button">
#           <img alt="My Account" height="20" src="https://justatic.com/v/20220131150237/shared/images/icons/svgfiles/white/profile.svg" width="20">
#           </img>
#          </div>
#          <div id="accounts-buttons-wrapper">
#           <span class="topnav-button login-buttons" id="login-buttons-wrapper">
#            <span class="login-buttons-wrapper">
#             <a class="login" data-directive="j-login" data-gtm-action="Header Account" data-gtm-category="Navigation" data-gtm-label="Log In" data-gtm-type="click" href="https://accounts.justia.com/?destination=https://www.justia.com/lawyers/new-york/new-york-city">
#              Log In
#             </a>
#             <a class="sign-up" href="https://accounts.justia.com/">
#              Sign Up
#             </a>
#            </span>
#           </span>
#          </div>
#         </div>
#         <div id="search-form-wrapper">
#          <form action="https://lawyers.justia.com/search" class="search-form jform two-fields" id="search-form" method="get">
#           <input data-latitude="40.78283400" data-longitude="-73.97538500" data-state_abbreviation="NY" data-state_id="33" data-user_state="05" id="location-field" type="hidden"/>
#           <input id="profile-id-field" name="profile-id-field" type="hidden" value=""/>
#           <input id="practice-id-field" name="practice-id-field" type="hidden" value=""/>
#           <input id="service-id-field" name="service-id-field" type="hidden" value=""/>
#           <input data-domain="lawyers.justia.com" id="cobrand-field" type="hidden" value="1"/>
#           <div class="input-wrapper first-input-wrapper">
#            <input autocomplete="off" class="practice-area-box-input" name="query" placeholder="Search Legal Issue or Lawyer Name" title="Search Legal Issue or Lawyer Name" type="text" value=""/>
#           </div>
#           <div class="input-wrapper second-input-wrapper">
#            <span class="middle">
#             in
#            </span>
#            <input autocomplete="off" class="location-box-input" data-domain="lawyers.justia.com" name="location" placeholder="City, State or Zip" title="City, State or Zip" type="text" value="New York City, NY"/>
#           </div>
#           <button type="submit">
#            <img alt="search" height="22" src="https://justatic.com/v/20220131150237/shared/images/icons/svgfiles/blue/search.svg" width="22"/>
#            <span class="visuallyhidden">
#             Search
#            </span>
#           </button>
#          </form>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div id="subnavigation">
#     <div class="subnavigation-wrapper">
#      <ul>
#       <li>
#        <a data-gtm-action="Header Navigation" data-gtm-category="Navigation" data-gtm-label="Find a Lawyer" data-gtm-type="click" href="https://www.justia.com/lawyers">
#         Find a Lawyer
#        </a>
#       </li>
#       <li>
#        <a data-gtm-action="Header Navigation" data-gtm-category="Navigation" data-gtm-label="Ask a Lawyer" data-gtm-type="click" href="https://answers.justia.com/">
#         Ask a Lawyer
#        </a>
#       </li>
#       <li>
#        <a data-gtm-action="Header Navigation" data-gtm-category="Navigation" data-gtm-label="Research the Law" data-gtm-type="click" href="https://www.justia.com/">
#         Research the Law
#        </a>
#       </li>
#       <li>
#        <a data-gtm-action="Header Navigation" data-gtm-category="Navigation" data-gtm-label="Law Schools" data-gtm-type="click" href="https://www.justia.com/law-schools/">
#         Law Schools
#        </a>
#       </li>
#       <li>
#        <a data-gtm-action="Header Navigation" data-gtm-category="Navigation" data-gtm-label="Laws &amp; Regs" data-gtm-type="click" href="https://law.justia.com/">
#         Laws &amp; Regs
#        </a>
#       </li>
#       <li>
#        <a data-gtm-action="Header Navigation" data-gtm-category="Navigation" data-gtm-label="Newsletters" data-gtm-type="click" href="https://law.justia.com/subscribe/">
#         Newsletters
#        </a>
#       </li>
#       <li>
#        <a data-gtm-action="Header Navigation" data-gtm-category="Navigation" data-gtm-label="Marketing Solutions" data-gtm-type="click" href="https://www.justia.com/marketing/">
#         Marketing Solutions
#        </a>
#        <div class="sublist">
#         <div class="sublist-section">
#          <ul>
#           <li class="sublist-section-title">
#            <a data-gtm-action="Header Navigation" data-gtm-category="Navigation" data-gtm-label="Justia Connect" data-gtm-type="click" href="https://www.justia.com/marketing/connect/">
#             Justia Connect
#            </a>
#           </li>
#           <li>
#            <a data-gtm-action="Header Navigation" data-gtm-category="Navigation" data-gtm-label="Basic Membership" data-gtm-type="click" href="https://www.justia.com/marketing/connect/">
#             Basic Membership
#            </a>
#           </li>
#           <li>
#            <a data-gtm-action="Header Navigation" data-gtm-category="Navigation" data-gtm-label="Pro Membership" data-gtm-type="click" href="https://www.justia.com/marketing/connect/#coming-soon-notify">
#             Pro Membership
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="sublist-section">
#          <ul>
#           <li class="sublist-section-title">
#            <a data-gtm-action="Header Navigation" data-gtm-category="Navigation" data-gtm-label="Justia Lawyer Directory" data-gtm-type="click" href="https://www.justia.com/marketing/lawyer-directory/">
#             Justia Lawyer Directory
#            </a>
#           </li>
#           <li>
#            <a data-gtm-action="Header Navigation" data-gtm-category="Navigation" data-gtm-label="Platinum Placements" data-gtm-type="click" href="https://www.justia.com/marketing/lawyer-directory/platinum/">
#             Platinum Placements
#            </a>
#           </li>
#           <li>
#            <a data-gtm-action="Header Navigation" data-gtm-category="Navigation" data-gtm-label="Gold Placements" data-gtm-type="click" href="https://www.justia.com/marketing/lawyer-directory/gold/">
#             Gold Placements
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="sublist-section">
#          <ul>
#           <li class="sublist-section-title">
#            <a data-gtm-action="Header Navigation" data-gtm-category="Navigation" data-gtm-label="Justia Elevate" data-gtm-type="click" href="https://www.justia.com/marketing/elevate/">
#             Justia Elevate
#            </a>
#           </li>
#           <li>
#            <a data-gtm-action="Header Navigation" data-gtm-category="Navigation" data-gtm-label="SEO" data-gtm-type="click" href="https://www.justia.com/marketing/elevate/search-engine-optimization/">
#             SEO
#            </a>
#           </li>
#           <li>
#            <a data-gtm-action="Header Navigation" data-gtm-category="Navigation" data-gtm-label="Websites &amp; LSA Management" data-gtm-type="click" href="https://www.justia.com/marketing/elevate/law-firm-websites/">
#             Websites
#            </a>
#           </li>
#           <li>
#            <a data-gtm-action="Header Navigation" data-gtm-category="Navigation" data-gtm-label="Blogs" data-gtm-type="click" href="https://www.justia.com/marketing/elevate/law-blogs/">
#             Blogs
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="sublist-section">
#          <ul>
#           <li class="sublist-section-title">
#            <a data-gtm-action="Header Navigation" data-gtm-category="Navigation" data-gtm-label="Justia Amplify" data-gtm-type="click" href="https://www.justia.com/marketing/amplify/">
#             Justia Amplify
#            </a>
#           </li>
#           <li>
#            <a data-gtm-action="Header Navigation" data-gtm-category="Navigation" data-gtm-label="PPC Management" data-gtm-type="click" href="https://www.justia.com/marketing/amplify/cpc-ppc/">
#             PPC Management
#            </a>
#           </li>
#           <li>
#            <a data-gtm-action="Header Navigation" data-gtm-category="Navigation" data-gtm-label="Google My Business" data-gtm-type="click" href="https://www.justia.com/marketing/amplify/google-my-business/">
#             Google My Business
#            </a>
#           </li>
#           <li>
#            <a data-gtm-action="Header Navigation" data-gtm-category="Navigation" data-gtm-label="Social Media" data-gtm-type="click" href="https://www.justia.com/marketing/amplify/social-media-networking/">
#             Social Media
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="sublist-section">
#          <ul>
#           <li class="sublist-section-title">
#            <a data-gtm-action="Header Navigation" data-gtm-category="Navigation" data-gtm-label="Justia Onward Blog" data-gtm-type="click" href="https://onward.justia.com/">
#             Justia Onward Blog
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </li>
#      </ul>
#     </div>
#    </div>
#   </header>
#   <main class="main-content has-topnav-padding font-opensans" id="main-content">
#    <nav aria-label="breadcrumb" class="breadcrumbs small-font font-helvetica">
#     <a href="http://www.justia.com/">
#      Justia
#     </a>
#     <span class="breadcrumb-separator">
#     </span>
#     <a href="https://www.justia.com/lawyers">
#      Lawyer Directory
#     </a>
#     <span class="breadcrumb-separator">
#     </span>
#     <a href="/lawyers/new-york">
#      New York
#     </a>
#     <span class="breadcrumb-separator">
#     </span>
#     <span class="last_crumb">
#      New York City Attorneys
#     </span>
#    </nav>
#    <div class="164380728733207" data-jtime="164380728733207" data-pagetype="main_page">
#     <div class="primary-content-wrapper">
#      <div class="primary-content">
#       <div class="wrapper jcard has-padding-30">
#        <h1 class="heading-1 listing-title">
#         New York City Lawyers
#        </h1>
#        <div class="landing-helpful-info">
#        </div>
#        <div class="clearfix tab-content-listing has-margin-bottom-20">
#         <div class="tab-group tab-group-hide-on-mobile has-padding-30 has-negative-sides-30 has-no-bottom-padding">
#          <div class="tabbed-head tab-wrap clearfix">
#           <div data-directive="j-tabs">
#            <strong class="tab-item tab-inline">
#             <span class="tab-item-text">
#              Browse By
#             </span>
#            </strong>
#            <span class="tab-item tab-item-selected">
#             <a class="tab-item-text" href="#tab-practice">
#              Practice Areas
#             </a>
#            </span>
#           </div>
#          </div>
#         </div>
#         <div class="tab-content-hide-on-mobile tab-content has-padding-30 has-negative-sides-30 has-no-bottom-padding">
#          <div class="" data-tab-content="practice" id="tab-practice">
#           <p>
#            <strong>
#             Find
#             <strong class="color-red">
#              New York City
#             </strong>
#             Lawyers  by Practice Area
#            </strong>
#           </p>
#           <div class="popular-box" id="popular-practice-areas">
#            <ul class="list-columns list-no-styles list-columns-two list-columns-three">
#             <li>
#              <a href="/lawyers/personal-injury/new-york/new-york-city" title="New York City, New York Personal Injury Lawyers">
#               Personal Injury
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/medical-malpractice/new-york/new-york-city" title="New York City, New York Medical Malpractice Lawyers">
#               Medical Malpractice
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/criminal-law/new-york/new-york-city" title="New York City, New York Criminal Law Lawyers">
#               Criminal Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/dui-dwi/new-york/new-york-city" title="New York City, New York DWI Lawyers">
#               DWI
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/family-law/new-york/new-york-city" title="New York City, New York Family Law Lawyers">
#               Family Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/divorce/new-york/new-york-city" title="New York City, New York Divorce Lawyers">
#               Divorce
#              </a>
#             </li>
#            </ul>
#            <ul class="list-columns list-no-styles list-columns-two list-columns-three">
#             <li>
#              <a href="/lawyers/bankruptcy/new-york/new-york-city" title="New York City, New York Bankruptcy Lawyers">
#               Bankruptcy
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/business-law/new-york/new-york-city" title="New York City, New York Business Law Lawyers">
#               Business Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/consumer-law/new-york/new-york-city" title="New York City, New York Consumer Law Lawyers">
#               Consumer Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/employment-law/new-york/new-york-city" title="New York City, New York Employment Law Lawyers">
#               Employment Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/estate-planning/new-york/new-york-city" title="New York City, New York Estate Planning Lawyers">
#               Estate Planning
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/foreclosure-defense/new-york/new-york-city" title="New York City, New York Foreclosure Defense Lawyers">
#               Foreclosure Defense
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/immigration-law/new-york/new-york-city" title="New York City, New York Immigration Law Lawyers">
#               Immigration Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/intellectual-property/new-york/new-york-city" title="New York City, New York Intellectual Property Lawyers">
#               Intellectual Property
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/nursing-home-abuse/new-york/new-york-city" title="New York City, New York Nursing Home Abuse Lawyers">
#               Nursing Home Abuse
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/probate/new-york/new-york-city" title="New York City, New York Probate Lawyers">
#               Probate
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/products-liability/new-york/new-york-city" title="New York City, New York Products Liability Lawyers">
#               Products Liability
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/real-estate-law/new-york/new-york-city" title="New York City, New York Real Estate Law Lawyers">
#               Real Estate Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/tax-law/new-york/new-york-city" title="New York City, New York Tax Law Lawyers">
#               Tax Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/traffic-tickets/new-york/new-york-city" title="New York City, New York Traffic Tickets Lawyers">
#               Traffic Tickets
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/workers-compensation/new-york/new-york-city" title="New York City, New York Workers' Compensation Lawyers">
#               Workers' Compensation
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#          <div class="" id="tab-practice-02">
#           <div class="alphabetical-box -collapsed" id="practices-box">
#            <ul class="list-columns list-no-styles list-columns-two list-columns-three">
#             <li>
#              <a href="/lawyers/agricultural-law/new-york/new-york-city" title="New York City, New York Agricultural Law Lawyers">
#               Agricultural Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/animal-dog-law/new-york/new-york-city" title="New York City, New York Animal &amp; Dog Law Lawyers">
#               Animal &amp; Dog Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/antitrust-law/new-york/new-york-city" title="New York City, New York Antitrust Law Lawyers">
#               Antitrust Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/appeals-appellate/new-york/new-york-city" title="New York City, New York Appeals &amp; Appellate Lawyers">
#               Appeals &amp; Appellate
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/arbitration-mediation/new-york/new-york-city" title="New York City, New York Arbitration &amp; Mediation Lawyers">
#               Arbitration &amp; Mediation
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/asbestos-mesothelioma/new-york/new-york-city" title="New York City, New York Asbestos &amp; Mesothelioma Lawyers">
#               Asbestos &amp; Mesothelioma
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/cannabis-marijuana-law/new-york/new-york-city" title="New York City, New York Cannabis &amp; Marijuana Law Lawyers">
#               Cannabis &amp; Marijuana Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/civil-rights/new-york/new-york-city" title="New York City, New York Civil Rights Lawyers">
#               Civil Rights
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/collections/new-york/new-york-city" title="New York City, New York Collections Lawyers">
#               Collections
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/communications-internet-law/new-york/new-york-city" title="New York City, New York Communications &amp; Internet Law Lawyers">
#               Communications &amp; Internet Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/construction-law/new-york/new-york-city" title="New York City, New York Construction Law Lawyers">
#               Construction Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/domestic-violence/new-york/new-york-city" title="New York City, New York Domestic Violence Lawyers">
#               Domestic Violence
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/education-law/new-york/new-york-city" title="New York City, New York Education Law Lawyers">
#               Education Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/elder-law/new-york/new-york-city" title="New York City, New York Elder Law Lawyers">
#               Elder Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/energy-oil-gas-law/new-york/new-york-city" title="New York City, New York Energy, Oil &amp; Gas Law Lawyers">
#               Energy, Oil &amp; Gas Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/entertainment-sports-law/new-york/new-york-city" title="New York City, New York Entertainment &amp; Sports Law Lawyers">
#               Entertainment &amp; Sports Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/environmental-law/new-york/new-york-city" title="New York City, New York Environmental Law Lawyers">
#               Environmental Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/government-administrative-law/new-york/new-york-city" title="New York City, New York Gov &amp; Administrative Law Lawyers">
#               Gov &amp; Administrative Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/health-care-law/new-york/new-york-city" title="New York City, New York Health Care Law Lawyers">
#               Health Care Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/insurance-claims/new-york/new-york-city" title="New York City, New York Insurance Claims Lawyers">
#               Insurance Claims
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/insurance-defense/new-york/new-york-city" title="New York City, New York Insurance Defense Lawyers">
#               Insurance Defense
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/international-law/new-york/new-york-city" title="New York City, New York International Law Lawyers">
#               International Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/juvenile-law/new-york/new-york-city" title="New York City, New York Juvenile Law Lawyers">
#               Juvenile Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/landlord-tenant/new-york/new-york-city" title="New York City, New York Landlord Tenant Lawyers">
#               Landlord Tenant
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/legal-malpractice/new-york/new-york-city" title="New York City, New York Legal Malpractice Lawyers">
#               Legal Malpractice
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/maritime-law/new-york/new-york-city" title="New York City, New York Maritime Law Lawyers">
#               Maritime Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/military-law/new-york/new-york-city" title="New York City, New York Military Law Lawyers">
#               Military Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/municipal-law/new-york/new-york-city" title="New York City, New York Municipal Law Lawyers">
#               Municipal Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/native-american-law/new-york/new-york-city" title="New York City, New York Native American Law Lawyers">
#               Native American Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/patents/new-york/new-york-city" title="New York City, New York Patents Lawyers">
#               Patents
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/securities-law/new-york/new-york-city" title="New York City, New York Securities Law Lawyers">
#               Securities Law
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/social-security-disability/new-york/new-york-city" title="New York City, New York Social Security Disability Lawyers">
#               Social Security Disability
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/stockbroker-investment-fraud/new-york/new-york-city" title="New York City, New York Stockbroker &amp; Investment Fraud Lawyers">
#               Stockbroker &amp; Investment Fraud
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/trademarks/new-york/new-york-city" title="New York City, New York Trademarks Lawyers">
#               Trademarks
#              </a>
#             </li>
#             <li>
#              <a href="/lawyers/white-collar-crime/new-york/new-york-city" title="New York City, New York White Collar Crime Lawyers">
#               White Collar Crime
#              </a>
#             </li>
#            </ul>
#           </div>
#           <p class="has-no-top-margin">
#            <a data-collapsed_text="Show All Practice Areas »" data-directive="j-expand" data-expanded_text="Show Fewer Practice Areas »" data-section="practices-box" data-target_class="-collapsed" href="#">
#             Show All Practice Areas »
#            </a>
#           </p>
#          </div>
#         </div>
#         <!-- /tab-content -->
#        </div>
#        <div class="has-topnav-padding-offset offset-block" id="lawyers-anchor">
#        </div>
#        <div class="-display-flex -flex-wrap" id="filter-results-wrapper">
#         <div class="width-100-v2" data-nosnippet="">
#          <form action="/lawyers/new-york/new-york-city" autocomplete="false" class="form-v2 width-100-v2 has-padding-full has-no-top-padding has-no-left-padding has-no-right-padding" data-pagination="pagination" data-results="main-listings-container" id="filter-form" method="post">
#           <input name="facets" type="hidden" value="1"/>
#           <input data-facet="page" data-param-defines-presence="false" name="page" type="hidden" value="1"/>
#           <input name="token" type="hidden" value="587d2bf95782eb94e86f191ec21ab5bf"/>
#           <div class="pills" data-directive="j-pills">
#            <!-- PILL[1] -->
#            <div class="pill tiny-font -hide-landscape-phone" data-default-text="Lawyer Rating" data-facets="rating" data-name="rating" id="rating-pill">
#             <span class="text font-w-bold">
#              <span class="pill-label">
#               Lawyer Rating
#              </span>
#              <span class="pill-icon cross hidden" id="rating-clear">
#               <svg class="jicon" role="img" title="cross" viewbox="0 0 270 270">
#                <use xlink:href="/justatic/shared/images/icons/simple-icons-sprite.svg#cross">
#                </use>
#               </svg>
#              </span>
#              <span class="pill-icon dropdown-arrow">
#               <svg class="jicon" role="img" title="down" viewbox="0 0 270 270">
#                <use xlink:href="/justatic/shared/images/icons/simple-icons-sprite.svg#down-fill">
#                </use>
#               </svg>
#              </span>
#             </span>
#             <div class="dropdown">
#              <fieldset class="dropdown-content has-margin-top-10 has-no-padding">
#               <strong class="dropdown-title bg-justia-blue color-white">
#                <legend>
#                 Lawyer Rating
#                </legend>
#                <span class="cursor-pointer dropdown-close cross">
#                 <svg class="jicon" role="img" title="cross" viewbox="0 0 270 270">
#                  <use xlink:href="/justatic/shared/images/icons/simple-icons-sprite.svg#cross">
#                  </use>
#                 </svg>
#                </span>
#               </strong>
#               <div class="dropdown-items bg-white">
#                <div class="jfld-group jfld-options-group">
#                 <div class="options-wrapper">
#                  <label class="form-option" for="form-filters-rating-9">
#                   <span class="jfld-block cursor-pointer">
#                    <input data-facet="rating" data-param-defines-presence="true" data-selected-value="Lawyer Rating of 9+" id="form-filters-rating-9" name="rating" type="radio" value="9"/>
#                    9+
#                    <img alt="Justia Lawyer Rating 9 or more" height="12" src="https://justatic.com/v/1/shared/images/icons/stars/stars-5-0.svg" title="Justia Lawyer Rating 9+" width="66"/>
#                   </span>
#                  </label>
#                  <label class="form-option" for="form-filters-rating-7">
#                   <span class="jfld-block cursor-pointer">
#                    <input data-facet="rating" data-param-defines-presence="true" data-selected-value="Lawyer Rating of 7+" id="form-filters-rating-7" name="rating" type="radio" value="7"/>
#                    7+
#                    <img alt="Justia Lawyer Rating 7 or more" height="12" src="https://justatic.com/v/1/shared/images/icons/stars/stars-4-0.svg" title="Justia Lawyer Rating 7 or more" width="66"/>
#                   </span>
#                  </label>
#                 </div>
#                </div>
#               </div>
#              </fieldset>
#             </div>
#            </div>
#            <!-- /PILL[1] -->
#            <!-- PILL[2] -->
#            <div class="pill tiny-font -hide-landscape-phone" data-default-text="Video Conferencing" data-facets="video_chat" data-name="video-chat" id="video-chat-pill">
#             <span class="text font-w-bold">
#              <span class="pill-label">
#               Video Conferencing
#              </span>
#              <span class="pill-icon cross hidden" id="video-chat-clear">
#               <svg class="jicon" role="img" title="cross" viewbox="0 0 270 270">
#                <use xlink:href="/justatic/shared/images/icons/simple-icons-sprite.svg#cross">
#                </use>
#               </svg>
#              </span>
#              <span class="pill-icon dropdown-arrow">
#               <svg class="jicon" role="img" title="down" viewbox="0 0 270 270">
#                <use xlink:href="/justatic/shared/images/icons/simple-icons-sprite.svg#down-fill">
#                </use>
#               </svg>
#              </span>
#             </span>
#             <div class="dropdown">
#              <div class="dropdown-content has-margin-top-10">
#               <strong class="dropdown-title bg-justia-blue color-white">
#                Video Conferencing
#                <span class="cursor-pointer dropdown-close cross">
#                 <svg class="jicon" role="img" title="cross" viewbox="0 0 270 270">
#                  <use xlink:href="/justatic/shared/images/icons/simple-icons-sprite.svg#cross">
#                  </use>
#                 </svg>
#                </span>
#               </strong>
#               <div class="dropdown-items bg-white">
#                <div class="jfld-group jfld-options-group">
#                 <div class="options-wrapper">
#                  <label class="form-option" for="form-filters-video-chat">
#                   <span class="jfld-block cursor-pointer">
#                    <input data-event-prefix="More Filters" data-facet="video_chat" data-param-defines-presence="true" data-selected-value="Video Conferencing" id="form-filters-video-chat" name="video_chat" type="checkbox" value="1"/>
#                    Offers Video Conferencing
#                   </span>
#                  </label>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <!-- /PILL[1] -->
#            <!-- PILL[2] -->
#            <div class="pill tiny-font -hide-landscape-phone" data-default-text="Free Consultation &amp; Fees" data-facets="free_consultation,accepts_credit_cards" data-name="misc" id="misc-pill">
#             <span class="text font-w-bold">
#              <span class="pill-label">
#               Free Consultation &amp; Fees
#              </span>
#              <span class="pill-icon cross hidden" id="misc-clear">
#               <svg class="jicon" role="img" title="cross" viewbox="0 0 270 270">
#                <use xlink:href="/justatic/shared/images/icons/simple-icons-sprite.svg#cross">
#                </use>
#               </svg>
#              </span>
#              <span class="pill-icon dropdown-arrow -keep-on-selected">
#               <svg class="jicon" role="img" title="down" viewbox="0 0 270 270">
#                <use xlink:href="/justatic/shared/images/icons/simple-icons-sprite.svg#down-fill">
#                </use>
#               </svg>
#              </span>
#             </span>
#             <div class="dropdown">
#              <div class="dropdown-content has-margin-top-10">
#               <strong class="dropdown-title bg-justia-blue color-white">
#                Free Consultation &amp; Fees
#                <span class="cursor-pointer dropdown-close cross">
#                 <svg class="jicon" role="img" title="cross" viewbox="0 0 270 270">
#                  <use xlink:href="/justatic/shared/images/icons/simple-icons-sprite.svg#cross">
#                  </use>
#                 </svg>
#                </span>
#               </strong>
#               <div class="dropdown-items bg-white">
#                <div class="jfld-group jfld-options-group">
#                 <div class="options-wrapper">
#                  <label class="form-option" for="form-filters-free-consultation">
#                   <span class="jfld-block cursor-pointer">
#                    <input data-event-prefix="Free Consultation &amp; Fees" data-facet="free_consultation" data-param-defines-presence="true" data-selected-value="Offers Free Consultation" id="form-filters-free-consultation" name="free_consultation" type="checkbox" value="1"/>
#                    Offers Free Consultation
#                   </span>
#                  </label>
#                  <label class="form-option" for="form-filters-accept-credit-cards">
#                   <span class="jfld-block cursor-pointer">
#                    <input data-event-prefix="Free Consultation &amp; Fees" data-facet="accepts_credit_cards" data-param-defines-presence="true" data-selected-value="Accepts Credit Cards" id="form-filters-accept-credit-cards" name="accepts_credit_cards" type="checkbox" value="1"/>
#                    Accepts Credit Cards
#                   </span>
#                  </label>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <!-- /PILL[2] -->
#            <!-- PILL[3] -->
#            <div class="pill tiny-font -hide-landscape-phone" data-default-text="More Filters" data-facets="claimed,photo,awards,biography,certifications,professional_associations,professional_experience,publications,speaking_engagements,videos,website,language,experience" data-name="more-filters" id="more-filters-pill">
#             <span class="text font-w-bold">
#              <span class="pill-label">
#               More Filters
#              </span>
#              <span class="pill-icon cross hidden" id="more-filters-clear">
#               <svg class="jicon" role="img" title="cross" viewbox="0 0 270 270">
#                <use xlink:href="/justatic/shared/images/icons/simple-icons-sprite.svg#cross">
#                </use>
#               </svg>
#              </span>
#              <span class="pill-icon dropdown-arrow">
#               <svg class="jicon" role="img" title="down" viewbox="0 0 270 270">
#                <use xlink:href="/justatic/shared/images/icons/simple-icons-sprite.svg#down-fill">
#                </use>
#               </svg>
#              </span>
#             </span>
#             <div class="dropdown set-maxlimit -max-landscape-tablet">
#              <div class="dropdown-content has-margin-top-10">
#               <strong class="dropdown-title bg-justia-blue color-white">
#                More Filters
#                <span class="cursor-pointer dropdown-close cross">
#                 <svg class="jicon" role="img" title="cross" viewbox="0 0 270 270">
#                  <use xlink:href="/justatic/shared/images/icons/simple-icons-sprite.svg#cross">
#                  </use>
#                 </svg>
#                </span>
#               </strong>
#               <div class="dropdown-items bg-white">
#                <div class="flex-columns -cols-gap-30 -cols-in-landscape-tablet width-100-v2">
#                 <div class="flex-col-wrapper">
#                  <div class="flex-col reset-width-below-landscape-tablet has-no-top-margin has-no-bottom-margin">
#                   <span class="normal-font -display-block has-margin-top-10 has-margin-bottom-10">
#                    <strong>
#                     Languages
#                    </strong>
#                   </span>
#                   <div class="jfld-group jfld-options-group">
#                    <div class="options-wrapper">
#                     <label class="form-option" for="form-filters-language-spanish">
#                      <span class="jfld-block cursor-pointer">
#                       <input data-event-prefix="More Filters: Language" data-facet="language" data-param-defines-presence="true" data-selected-value="Spanish" id="form-filters-language-spanish" name="language" type="radio" value="627"/>
#                       Spanish
#                      </span>
#                     </label>
# ...
#        <li>
#         <a data-gtm-action="Content" data-gtm-category="Navigation" data-gtm-label="Directory - Listings - Nearby County" data-gtm-type="click" href="/lawyers/new-york/new-york-county" title="New York County Attorneys">
#          New York County
#         </a>
#        </li>
#        <li>
#         <a data-gtm-action="Content" data-gtm-category="Navigation" data-gtm-label="Directory - Listings - Nearby County" data-gtm-type="click" href="/lawyers/new-york/bronx-county" title="Bronx County Attorneys">
#          Bronx County
#         </a>
#        </li>
#        <li>
#         <a data-gtm-action="Content" data-gtm-category="Navigation" data-gtm-label="Directory - Listings - Nearby County" data-gtm-type="click" href="/lawyers/new-york/kings-county" title="Kings County Attorneys">
#          Kings County
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="jcard has-padding-content-block-30 block text-center small-font">
#       <a class="button button-bright -default-fz" href="https://lawyers.justia.com/faq">
#        FAQ
#       </a>
#       <a class="button button-bright -default-fz" href="https://lawyers.justia.com/lawyer-directory-listings">
#        Lawyers Get Listed
#       </a>
#      </div>
#      <div class="jcard has-padding-content-block-30 block">
#       <p class="heading-4">
#        New York City Legal Aid &amp; Pro Bono Services
#       </p>
#       <p>
#        <strong>
#         <a href="https://lawyers.justia.com/legalservice/housing-conservation-coordinators-11347">
#          Housing Conservation Coordinators
#         </a>
#        </strong>
#        <br/>
#        (212) 541-5996
#        <br/>
#        New York, NY
#       </p>
#       <hr class="hr"/>
#       <p>
#        <strong>
#         <a href="https://lawyers.justia.com/legalservice/goddard-riverside-community-center-west-side-sro-law-project-9462">
#          Goddard-Riverside Community Center West Side SRO Law Project
#         </a>
#        </strong>
#        <br/>
#        (212) 799-9638
#        <br/>
#        New York, NY
#       </p>
#       <a class="button pull-right" href="/lawyers/new-york/new-york-city/legal-aid-and-pro-bono-services">
#        Show More
#       </a>
#      </div>
#      <div class="jcard has-padding-content-block-30 block">
#       <p class="heading-4">
#        Researching Attorney Discipline
#       </p>
#       <p>
#        <a href="https://lawyers.justia.com/attorney-discipline">
#         Find out whether an attorney has ever been disciplined.
#        </a>
#       </p>
#      </div>
#      <div class="jcard has-padding-content-block-30 block">
#       <p class="heading-4">
#        Resources for Lawyers
#       </p>
#       <ul>
#        <li>
#         <a href="https://lawyers.justia.com/lawyer-directory-badges">
#          About Justia Lawyer Directory Badges
#         </a>
#        </li>
#        <li>
#         <a href="https://lawyers.justia.com/faq">
#          Lawyer Directory FAQs
#         </a>
#        </li>
#        <li>
#         <a href="https://lawyers.justia.com/new-profile">
#          Claim your Profile
#         </a>
#        </li>
#        <li>
#         <a href="https://www.justia.com/marketing/lawyer-directory/">
#          About Premium Placements
#         </a>
#        </li>
#        <li>
#         <a href="https://lawyers.justia.com/about-the-justia-lawyer-rating-reviews">
#          About Justia Lawyer Rating and Reviews
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <!-- /primary-content-wrapper -->
#    </div>
#    <!-- /listings_container -->
#    <div class="comparison-tool" data-directive="j-compare" data-type="tool">
#     <a class="toggle -hide-tablet" data-event-action="Profile" data-event-category="Directory" data-event-expand-label="Show Widget" data-section="comparison-content" href="#">
#      <span class="visuallyhidden">
#       Toggle tool
#      </span>
#      <svg class="jicon -fill-red" role="img" title="Toggle" viewbox="0 0 270 270">
#       <use xlink:href="/justatic/shared/images/icons/simple-icons-sprite.svg#down">
#       </use>
#      </svg>
#     </a>
#     <div class="tabs">
#      <div class="tab-item-selected tab-item -recent">
#       <a class="tab-item-text tab-item-text-selected-visible" data-event-label="Recent" href="#recent">
#        <span class="icon">
#         <svg class="jicon -fill-boulder -small has-no-margin" role="img" title="Recently Viewed" viewbox="0 0 270 270">
#          <use xlink:href="/justatic/shared/images/icons/simple-icons-sprite.svg#see">
#          </use>
#         </svg>
#         <span class="counter -recent" data-counter-type="simple">
#          (0)
#         </span>
#        </span>
#        <span class="text line-height-1-1 small-font">
#         Recent
#         <span class="counter -recent" data-counter-type="simple">
#          (0)
#         </span>
#        </span>
#       </a>
#      </div>
#      <div class="tab-item -saved">
#       <a class="tab-item-text" data-event-label="Saved" href="#save">
#        <span class="icon">
#         <svg class="jicon -fill-boulder has-no-margin" role="img" title="Saved" viewbox="0 0 270 270">
#          <use xlink:href="/justatic/shared/images/icons/simple-icons-sprite.svg#bookmark">
#          </use>
#         </svg>
#         <span class="counter -save" data-counter-type="simple">
#          (0)
#         </span>
#        </span>
#        <span class="text line-height-1-1 small-font">
#         Saved
#         <span class="counter -save" data-counter-type="simple">
#          (0)
#         </span>
#        </span>
#       </a>
#      </div>
#      <div class="tab-item -compare">
#       <a class="tab-item-text" data-event-label="Compare" href="#compare">
#        <span class="icon">
#         <div class="compare-btn -only-icon">
#          <div class="square">
#           <svg class="jicon -fill-blue -small" role="img" title="check" viewbox="0 0 270 270">
#            <use xlink:href="/justatic/shared/images/icons/simple-icons-sprite.svg#check">
#            </use>
#           </svg>
#          </div>
#         </div>
#         <span class="counter -compare">
#          (0/3)
#         </span>
#        </span>
#        <span class="text line-height-1-1 small-font">
#         Compare
#         <span class="counter -compare">
#          (0/3)
#         </span>
#        </span>
#       </a>
#      </div>
#     </div>
#     <div class="container -collapsed" id="comparison-content">
#      <div class="tools">
#       <div class="tool -recent" id="recent">
#        <div class="lawyers-in-row -tool clearfix -recently-viewed -empty" data-cookie-limit="50" data-elements-limit="3" id="recent-container">
#        </div>
#        <p class="no-items tcenter width-100-v2">
#         There are no recently viewed profiles.
#        </p>
#        <div class="button-container">
#         <a class="button button-ghost" data-gtm-action="Profile" data-gtm-category="Directory" data-gtm-label="View All Recent Profiles" data-gtm-type="click" href="https://lawyers.justia.com/recent" rel="nofollow">
#          View all
#         </a>
#        </div>
#       </div>
#       <div class="tool -save" id="save">
#        <div class="lawyers-in-row -tool clearfix -saved -empty" data-cookie-limit="50" data-elements-limit="3" id="save-container">
#        </div>
#        <p class="no-items tcenter width-100-v2">
#         There are no saved profiles.
#        </p>
#        <div class="button-container">
#         <a class="button button-ghost" data-gtm-action="Profile" data-gtm-category="Directory" data-gtm-label="View All Saved Profiles" data-gtm-type="click" href="https://lawyers.justia.com/saved" rel="nofollow">
#          View all
#         </a>
#        </div>
#       </div>
#       <div class="tool -compare" id="compare">
#        <div class="lawyers-in-row -tool clearfix -compare" data-cookie-limit="3" data-items-minimum="2" id="compare-container">
#        </div>
#        <p class="no-items tcenter width-100-v2">
#         There are no profiles to compare.
#        </p>
#        <div class="button-container">
#         <a class="button button-red button-disabled" data-gtm-action="Profile" data-gtm-category="Directory" data-gtm-label="Compare Profiles" data-gtm-type="click" href="https://lawyers.justia.com/compare" rel="nofollow">
#          Compare
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </main>
#   <div class="short" data-directive="j-gdpr" data-privacy-policy-url="https://www.justia.com/privacy-policy/" id="footer">
#    <div class="wrapper">
#     <div class="copyright">
#      <span class="site">
#       <span class="social-media">
#        <a class="fb icon" href="https://www.facebook.com/justia" target="_blank" title="Facebook">
#         <img alt="Facebook" data-gtm-action="Footer" data-gtm-category="Navigation" data-gtm-label="Social Media - Facebook" data-gtm-type="click" height="50" src="https://justatic.com/v/20220131150237/shared/images/icons/version2/social/facebook.svg" width="50"/>
#        </a>
#        <a class="twitter icon" href="https://twitter.com/justiacom" target="_blank" title="Twitter">
#         <img alt="Twitter" data-gtm-action="Footer" data-gtm-category="Navigation" data-gtm-label="Social Media - Twitter" data-gtm-type="click" height="50" src="https://justatic.com/v/20220131150237/shared/images/icons/version2/social/twitter.svg" width="50"/>
#        </a>
#        <a class="linkedin icon" href="https://www.linkedin.com/company/justia" target="_blank" title="LinkedIn">
#         <img alt="LinkedIn" data-gtm-action="Footer" data-gtm-category="Navigation" data-gtm-label="Social Media - LinkedIn" data-gtm-type="click" height="50" src="https://justatic.com/v/20220131150237/shared/images/icons/version2/social/linkedin.svg" width="50"/>
#        </a>
#        <a class="justia icon" href="https://lawyers.justia.com/organization/justia-inc-16302" title="Justia Lawyer Directory">
#         <img alt="Justia" data-gtm-action="Footer" data-gtm-category="Navigation" data-gtm-label="Social Media - Justia Lawyer Directory" data-gtm-type="click" height="50" src="https://justatic.com/v/20220131150237/shared/images/icons/version2/social/justia.svg" width="50"/>
#        </a>
#       </span>
#       <span class="credits">
#        © 2022
#        <a data-gtm-action="Footer" data-gtm-category="Navigation" data-gtm-label="Copyright" data-gtm-type="click" href="https://www.justia.com/">
#         Justia
#        </a>
#       </span>
#      </span>
#      <span class="nav">
#       <a data-gtm-action="Footer" data-gtm-category="Navigation" data-gtm-label="Justia Connect" data-gtm-type="click" href="https://connect.justia.com/">
#        Justia Connect
#       </a>
#       <a data-gtm-action="Footer" data-gtm-category="Navigation" data-gtm-label="Legal Portal" data-gtm-type="click" href="https://www.justia.com/">
#        Legal Portal
#       </a>
#       <a data-gtm-action="Footer" data-gtm-category="Navigation" data-gtm-label="Company" data-gtm-type="click" href="https://company.justia.com/">
#        Company
#       </a>
#       <a data-gtm-action="Footer" data-gtm-category="Navigation" data-gtm-label="Help" data-gtm-type="click" href="https://support.justia.com/">
#        Help
#       </a>
#       <a data-gtm-action="Footer" data-gtm-category="Navigation" data-gtm-label="Terms of Service" data-gtm-type="click" href="https://www.justia.com/terms-of-service/">
#        Terms of Service
#       </a>
#       <a data-gtm-action="Footer" data-gtm-category="Navigation" data-gtm-label="Privacy Policy" data-gtm-type="click" href="https://www.justia.com/privacy-policy/">
#        Privacy Policy
#       </a>
#       <a class="nowrap" data-gtm-action="Footer" data-gtm-category="Navigation" data-gtm-label="Marketing Solutions" data-gtm-type="click" href="https://www.justia.com/marketing/">
#        Marketing Solutions
#       </a>
#      </span>
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    <!--//--><![CDATA[//><!--
# 	window.trackerMetadata = {
#     	"p_s_id": 33,
#     	"p_co_id": 20,
#     	"p_ci_id": 7,
#     	"p_m_id": 2048,
#     	"p_pa_id": null,
#     	"geo": false,
#
#
#     	"localized": false
# 	}
# //--><!]]>
#   </script>
#   <script async="" defer="" src="https://justatic.com/v/20220131150237/shared/js/jld.js">
#   </script>
#   <script type="application/javascript">
#    window.profiles = {"1492272":{"name":"Eric Weiss Esq.","picture":"\/profile-images\/1492272-1444778637-s.jpg","link":"\/lawyer\/eric-weiss-esq-1492272","location":"White Plains, NY"},"1531612":{"name":"Steven M. Yurkonis","picture":"\/profile-images\/1531612-1579277449-s.jpg","link":"\/lawyer\/steven-m-yurkonis-1531612","location":"Frackville, PA"},"1666096":{"name":"Donnell Much","picture":"\/profile-images\/1666096-1629823103-s.jpeg","link":"\/lawyer\/donnell-much-1666096","location":"New York, NY"},"1280463":{"name":"Nathalie L. Bell","picture":"\/profile-images\/1280463-1610664482-s.jpg","link":"\/lawyer\/nathalie-l-bell-1280463","location":"Syosset, NY"},"1208105":{"name":"Jenice Malecki","picture":"\/profile-images\/1208105-1556922837-s.jpg","link":"\/lawyer\/jenice-malecki-1208105","location":"New York, NY"},"1185294":{"name":"Jeffrey Michael Haber","picture":"\/profile-images\/1185294-1475268387-s.jpg","link":"\/lawyer\/jeffrey-michael-haber-1185294","location":"Melville, NY"},"1498532":{"name":"Mr. John P. Fazzio III Esq.","picture":"\/profile-images\/1498532-1521052645-s.jpg","link":"\/lawyer\/mr-john-p-fazzio-iii-esq-1498532","location":"Hoboken, NJ"},"1500773":{"name":"Dorina Cela","picture":"\/profile-images\/1500773-1447125664-s.jpg","link":"\/lawyer\/dorina-cela-1500773","location":"New York, NY"},"1412280":{"name":"Robert L. Herskovits","picture":"\/profile-images\/1412280-1572295072-s.jpg","link":"\/lawyer\/robert-l-herskovits-1412280","location":"New York, NY"},"1313904":{"name":"Adam Gana","picture":"\/profile-images\/1313904-1501712823-s.jpg","link":"\/lawyer\/adam-gana-1313904","location":"Montclair, NJ"},"1175031":{"name":"Carl Scott Spector","picture":"\/profile-images\/1175031-1591134515-s.jpg","link":"\/lawyer\/carl-scott-spector-1175031","location":"Glen Rock, NJ"},"1509356":{"name":"Jonathan E. May","picture":"\/profile-images\/1509356-1566154581-s.jpg","link":"\/lawyer\/jonathan-e-may-1509356","location":"New York City, NY"},"1499377":{"name":"Batya Ehrens","picture":"\/profile-images\/1499377-1452724158-s.jpg","link":"\/lawyer\/batya-ehrens-1499377","location":"New York, NY"},"1102121":{"name":"Bruce Provda","picture":"\/profile-images\/1102121-1444782286-s.jpg","link":"\/lawyer\/bruce-provda-1102121","location":"New York, NY"},"1411982":{"name":"Joshua Friedman","picture":"\/profile-images\/1411982-1449692537-s.png","link":"\/lawyer\/joshua-friedman-1411982","location":"New York, NY"},"1285271":{"name":"Arkady Bukh","picture":"\/profile-images\/1285271-1444766504-s.jpg","link":"\/lawyer\/arkady-bukh-1285271","location":"New York, NY"},"1330361":{"name":"Joseph H. Nivin","picture":"\/profile-images\/1330361-1516552635-s.jpg","link":"\/lawyer\/joseph-h-nivin-1330361","location":"New York, NY"},"1638620":{"name":"Adam Eugene Deitz","picture":"\/profile-images\/1638620-1626365485-s.jpeg","link":"\/lawyer\/adam-eugene-deitz-1638620","location":"Portland, OR"},"1499379":{"name":"V. Jonas Urba","picture":"\/profile-images\/1499379-1575413470-s.jpg","link":"\/lawyer\/v-jonas-urba-1499379","location":"New York, NY"},"1263259":{"name":"George Vomvolakis","picture":"\/profile-images\/1263259-1444771939-s.jpg","link":"\/lawyer\/george-vomvolakis-1263259","location":"New York, NY"},"1594476":{"name":"Britt N. Burner","picture":"\/profile-images\/1594476-1599677076-s.jpg","link":"\/lawyer\/britt-n-burner-1594476","location":"New York, NY"},"1236057":{"name":"Adam Leitman Bailey","picture":"\/profile-images\/1236057-1575649502-s.jpg","link":"\/lawyer\/adam-leitman-bailey-1236057","location":"New York, NY"},"780988":{"name":"Ralph Behr","picture":"\/profile-images\/780988-1533159897-s.jpg","link":"\/lawyer\/ralph-behr-780988","location":"Boca Raton, FL"},"1502885":{"name":"Julie Rendelman","picture":"\/profile-images\/1502885-1641780792-s.jpeg","link":"\/lawyer\/julie-rendelman-1502885","location":"New York, NY"},"1144588":{"name":"Daniel E. Katz","picture":"\/profile-images\/1144588-1592413051-s.png","link":" ...
#   </script>
#  </body>
# </html>

# %%
# results with lawyer's profiles
results = soup.find_all('div', {'data-vars-action':'OrganicListing'})

# %%
# Find name of each lawyer
results[0].find('strong', {'class':'lawyer-name'}).get_text().strip()
# Out:
# 'Adam Leitman Bailey'

# %%
# Find short bias
results[0].find('span', {'class':'-hide-landscape-phone'}).get_text()
# Out:
# 'New York, NY Attorney with 26 years of experience'

# %%
# Find specialization
results[0].find('span', {'class':'-practices iconed-line-small'}).get_text().strip()
# Out:
# 'Business, Foreclosure Defense, Landlord Tenant and Real Estate'

# %%
# Find university
results[0].find('span', {'class':'-hide-tablet -law-schools iconed-line-small'}).get_text().strip()
# Out:
# 'Syracuse University College of Law'

# %%
# Find address
results[0].find('span', {'class':'-address -hide-landscape-tablet'}).get_text().strip().replace("\t", "").replace("\n", ",")
# Out:
# 'One Battery Park Plaza,Eighteenth Floor,New York,NY 10004'

# %%
# Find phone number
results[0].find('strong', {'class':'-phone'}).get_text().strip('\n')
# Out:
# '(212) 825-0365 '

# %%
# Find e-mail link
results[0].find('a', {'class':'-group-button -email'}).get('href')
# Out:
# 'https://lawyers.justia.com/lawyer/adam-leitman-bailey-1236057/contact'

# %%
# Everything into a loop
name = []
short_bias = []
specialization = []
university = []
address = []
phone = []
mail = []

# %%
for result in results:
    # Name
    try:
        name.append(result.find('strong', {'class':'lawyer-name'}).get_text().strip())
    except:
        name.append(np.nan)
         
    # Short Bias
    try:
        short_bias.append(result.find('span', {'class':'-hide-landscape-phone'}).get_text())
    except:
        short_bias.append(np.nan)
        
    # Specialization
    try:
        specialization.append(result.find('span', {'class':'-practices iconed-line-small'}).get_text().strip())
    except:
        specialization.append(np.nan)
        
    # University
    try:    
        university.append(result.find('span', {'class':'-hide-tablet -law-schools iconed-line-small'}).get_text().strip())
    except:
        university.append(np.nan)
        
    # Address
    try:
        address.append(result.find('span', {'class':'-address -hide-landscape-tablet'}).get_text().strip().replace("\t", "").replace("\n", ","))
    except:
        address.append(np.nan)
        
    # Phone
    try:
        phone.append(result.find('strong', {'class':'-phone'}).get_text().strip('\n'))
    except:
        phone.append(np.nan)
        
    # Mail
    try:
        mail.append(result.find('a', {'class':'-group-button -email'}).get('href'))
    except:
        mail.append(np.nan)

# %%
# Create dataframe with 
justia_df = pd.DataFrame(list(zip(name, short_bias, specialization, university, address, phone, mail)),
                         columns = ['name','short_bias','specialization','university','address','phone','mail'])

# %%
justia_df.head(2)
# Out:
#                   name                                         short_bias  \
# 0  Adam Leitman Bailey  New York, NY Attorney with 26 years of experience
# 1        Russel Morgan                                New York, NY Lawyer
#
#                                       specialization  \
# 0  Business, Foreclosure Defense, Landlord Tenant...
# 1    Elder, Estate Planning, Probate and Real Estate
#
#                            university  \
# 0  Syracuse University College of Law
# 1                 New York Law School
#
#                                              address            phone  \
# 0  One Battery Park Plaza,Eighteenth Floor,New Yo...  (212) 825-0365
# 1         299 Broadway, 17th Floor,New York,NY 10007  (212) 561-4299
#
#                                                 mail
# 0  https://lawyers.justia.com/lawyer/adam-leitman...
# 1  https://lawyers.justia.com/lawyer/russel-morga...

# %%
# Dataframe into Excel
justia_df.to_excel('justia_df.xlsx', index=False)

# %% [markdown]
# ## Pagination - 20 pages

# %%
name = []
short_bias = []
specialization = []
university = []
address = []
phone = []
mail = []


for i in range(1, 21):
    # Store website in a variable
    website = f'https://www.justia.com/lawyers/new-york/new-york-city?page={i}'
    
    # Get request
    response = requests.get(website)
    
    # Soup object
    soup = bs.BeautifulSoup(response.content, 'html.parser')
    
    # results with lawyer's profiles
    results = soup.find_all('div', {'data-vars-action':'OrganicListing'})
    
    for result in results:
        # Name
        try:
            name.append(result.find('strong', {'class':'lawyer-name'}).get_text().strip())
        except:
            name.append(np.nan)
         
        # Short Bias
        try:
            short_bias.append(result.find('span', {'class':'-hide-landscape-phone'}).get_text())
        except:
            short_bias.append(np.nan)
        
        # Specialization
        try:
            specialization.append(result.find('span', {'class':'-practices iconed-line-small'}).get_text().strip())
        except:
            specialization.append(np.nan)
        
        # University
        try:    
            university.append(result.find('span', {'class':'-hide-tablet -law-schools iconed-line-small'}).get_text().strip())
        except:
            university.append(np.nan)
        
        # Address
        try:
            address.append(result.find('span', {'class':'-address -hide-landscape-tablet'}).get_text().strip().replace("\t", "").replace("\n", ","))
        except:
            address.append(np.nan)
        
        # Phone
        try:
            phone.append(result.find('strong', {'class':'-phone'}).get_text().strip('\n'))
        except:
            phone.append(np.nan)
        
        # Mail
        try:
            mail.append(result.find('a', {'class':'-group-button -email'}).get('href'))
        except:
            mail.append(np.nan)

# %%
justia_df_2 = pd.DataFrame(list(zip(name, short_bias, specialization, university, address, phone, mail)),
                         columns = ['name','short_bias','specialization','university','address','phone','mail'])

# %%
# Postgres
engine = sqlalchemy.create_engine('postgres://postgres:12345@localhost:5432')

justia_df_2.to_sql('lawyers_ny', engine, index = False)

# %%
con = engine.connect()
print(engine.table_names())
# Out:
# ['lawyers_ny', 'retornos_fci']

# %%
# Convert query into DataFrame
rs = con.execute('SELECT * FROM lawyers_ny LIMIT 20')
lay_20_df = pd.DataFrame(rs, columns = rs.keys())
con.close()

# %%
lay_20_df.head(2)
# Out:
#              name                                         short_bias  \
# 0   V. Jonas Urba  New York, NY Attorney with 33 years of experience
# 1  Michael Brevda  New York City, NY Lawyer with 12 years of expe...
#
#   specialization                                  university  \
# 0     Employment         Valparaiso University School of Law
# 1   Nursing Home  University of Florida Levin College of Law
#
#                                            address            phone  \
# 0    200 Park Ave. Ste 1700,New York,NY 10166-0005  (212) 731-4776
# 1  325 W 38th Street,#1101B,New York City,NY 10018  (646) 969-5855
#
#                                                 mail
# 0  https://lawyers.justia.com/lawyer/v-jonas-urba...
# 1  https://lawyers.justia.com/lawyer/michael-brev...
